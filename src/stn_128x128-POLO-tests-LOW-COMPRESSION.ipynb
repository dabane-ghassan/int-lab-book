# %% [markdown]
# # Loading Modules

# %%
#import sys
#sys.path.append('../../../Julia Gachot 2019/POLO/dev')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
from LogGabor import LogGabor
from what_where.main import init, MNIST
from what_where.where import RetinaFill, WhereShift, RetinaBackground, RetinaMask
from POLO.PYramid2 import cropped_pyramid, local_filter, get_K, log_gabor_transform
from POLO.PYramid2 import inverse_pyramid, get_K_inv, inverse_gabor
from utils import view_data
from typing import List, Tuple
# Out:
# Default lg shape= 32 32

# %% [markdown]
# # Loading the Data

# %% [markdown]
# - Loading the data with the parameters given in the .json file for the What/Where model

# %%
args = init(filename='../data/2020-07-01')
args
# Out:
# {'w': 28,
#  'minibatch_size': 100,
#  'train_batch_size': 50000,
#  'test_batch_size': 10000,
#  'noise_batch_size': 1000,
#  'mean': 0.1307,
#  'std': 0.3081,
#  'what_offset_std': 15,
#  'what_offset_max': 25,
#  'N_pic': 128,
#  'offset_std': 30,
#  'offset_max': 34,
#  'noise': 0.75,
#  'contrast': 0.7,
#  'sf_0': 0.1,
#  'B_sf': 0.1,
#  'do_mask': True,
#  'N_theta': 6,
#  'N_azimuth': 24,
#  'N_eccentricity': 10,
#  'N_phase': 2,
#  'rho': 1.41,
#  'bias_deconv': True,
#  'p_dropout': 0.0,
#  'dim1': 1000,
#  'dim2': 1000,
#  'lr': 0.005,
#  'do_adam': True,
#  'bn1_bn_momentum': 0.5,
#  'bn2_bn_momentum': 0.5,
#  'momentum': 0.3,
#  'epochs': 60,
#  'num_processes': 1,
#  'no_cuda': False,
#  'log_interval': 100,
#  'verbose': 1,
#  'filename': '../data/2020-07-01',
#  'seed': 2019,
#  'N_cv': 10,
#  'do_compute': True,
#  'save_model': True}

# %% [markdown]
# # Log Gabor parameters

# %%
width = 64

n_levels = 2 

base_levels = 2

 

n_color = 1

r_min = width / 4 

r_max = width / 2 

n_sublevel = n_eccentricity = 4

n_azimuth = 16 *2

n_theta = 8

n_phase = 1

# %%
gauss = False
do_mask = False
color = False

# %%
pe = {'N_X': width, 'N_Y': width, 'do_mask': do_mask, 'base_levels':
          base_levels, 'n_theta': 0, 'B_sf': np.inf, 'B_theta': np.inf ,
      'use_cache': True, 'figpath': 'results', 'edgefigpath':
          'results/edges', 'matpath': 'cache_dir', 'edgematpath':
          'cache_dir/edges', 'datapath': 'database/', 'ext': '.pdf', 'figsize':
          14.0, 'formats': ['pdf', 'png', 'jpg'], 'dpi': 450, 'verbose': 0}   

lg = LogGabor(pe)

print('lg shape=', lg.pe.N_X, lg.pe.N_Y)
# Out:
# lg shape= 64 64

# %%
K = get_K(width=width,
          n_sublevel = n_sublevel, 
          n_azimuth = n_azimuth, 
          n_theta = n_theta,
          n_phase = n_phase, 
          r_min = r_min, 
          r_max = r_max, 
          log_density_ratio = 2, 
          verbose=True,
          lg=lg)

plt.plot(K.flatten())
plt.title('K coefficients')
# Out:
# i_sublevel, sf_0, radius 0 0.18033688011112042 16.0
# i_sublevel, sf_0, radius 1 0.15164463602348005 19.027313840043536
# i_sublevel, sf_0, radius 2 0.12751743082459868 22.62741699796952
# i_sublevel, sf_0, radius 3 0.10722895046276856 26.908685288118864
# K shape= torch.Size([64, 64, 4, 32, 8, 1])
# K min max= tensor(-0.2759) tensor(1.)
# Text(0.5, 1.0, 'K coefficients')

# %% [markdown]
# ### Honeycomb space coverage tests

# %%
plt.figure(figsize=(20,3))
for i_theta in range(n_theta):
    coefs = torch.zeros((n_sublevel, n_azimuth, n_theta, n_phase))
    coefs[0, n_azimuth//2, i_theta, 0] = 1
    img_dis = torch.tensordot(K, coefs, dims=4)
    plt.subplot(1,n_theta,i_theta+1)
    plt.imshow(img_dis.numpy()[:, :, ...], cmap='gray')

# %%
plt.figure(figsize=(20,6))
for i_az in range(n_azimuth):
    coefs = torch.zeros((n_sublevel, n_azimuth, n_theta, n_phase))
    coefs[:, i_az, 0, 0] = 1
    img_dis = torch.tensordot(K, coefs, dims=4)
    plt.subplot(2,n_azimuth//2,i_az+1)
    plt.imshow(img_dis.numpy()[:, :, ...], cmap='gray')

# %%
plt.figure(figsize=(12,6))
coefs = torch.zeros((n_sublevel, n_azimuth, n_theta, n_phase))
coefs[:, :, 2:3, 0] = torch.ones((n_sublevel, n_azimuth, 1))
img_dis = torch.tensordot(K, coefs, dims=4)
plt.subplot(1,2,1)
plt.imshow(img_dis.numpy(), cmap='gray', aspect='auto')
plt.subplot(1,2,2)
_=plt.plot(img_dis.numpy())

# %% [markdown]
# ## inverse Log Gabor

# %%
K.shape
# Out:
# torch.Size([64, 64, 4, 32, 8, 1])

# %%
K_inv = get_K_inv(K, 
                  width=width, 
                  n_sublevel = n_sublevel, 
                  n_azimuth = n_azimuth, 
                  n_theta = n_theta, 
                  n_phase = n_phase)
plt.plot(K_inv.flatten())
plt.title('K_inv coefficients')
# Out:
# Filter tensor shape= torch.Size([64, 64, 4, 32, 8, 1])
# Reshaped filter tensor= torch.Size([4096, 1024])
# Tensor shape= torch.Size([1024, 4096])
# Text(0.5, 1.0, 'K_inv coefficients')

# %%
log_gabor_rosace = 100 * torch.ones(1, n_levels, n_eccentricity, n_azimuth, n_theta, n_phase)
plt.figure()
print('log_gabor_rosace shape: ', log_gabor_rosace.shape)

img_crop_rosace=inverse_gabor(log_gabor_rosace, K_inv)
print('img_crop_rosace shape:', img_crop_rosace.shape)
#img_crop_rosace[:,-1,...] = 128 
full_rosace = inverse_pyramid(img_crop_rosace, color=color, gauss=gauss, n_levels=n_levels, base_levels=base_levels)
full_rosace = full_rosace.detach().permute(0,2,3,1).numpy().clip(0,255).astype('uint8')
#ax = tensor_image_cmp(full_img_rec, full_img_rec_rec)
plt.figure(figsize=(7,7))
plt.imshow(full_rosace.squeeze(), cmap='gray')
# Out:
# log_gabor_rosace shape:  torch.Size([1, 2, 4, 32, 8, 1])
# img_crop_rosace shape: torch.Size([1, 2, 64, 64])

# %%
2*16*8, 32*32
# Out:
# (256, 1024)

# %%
img_crop_rosace.shape
# Out:
# torch.Size([1, 2, 64, 64])

# %% [markdown]
# ### Adapted cropped pyramid (squeezed tensor)

# %%
class CroppedPyramid(object):
    def __init__(self, width, 
                 base_levels, 
                 color=color, 
                 do_mask=do_mask, 
                 verbose=False, 
                 n_levels=None, 
                 color_mode='rgb'):
        self.width = width
        self.base_levels = base_levels
        self.color = color
        self.do_mask = do_mask
        self.verbose = verbose
        self.n_levels = n_levels
        self.color_mode = color_mode

    def __call__(self, img):
        img_crop, level_size = cropped_pyramid(img.unsqueeze(1), 
                                               width=self.width, 
                                               base_levels=self.base_levels,
                                               color=self.color, 
                                               do_mask=self.do_mask, 
                                               verbose=self.verbose,
                                               squeeze=True,
                                               gauss=gauss,
                                               n_levels=self.n_levels,
                                               color_mode=self.color_mode)
        return img, img_crop

# %% [markdown]
# ### LogGaborTransform

# %%
class LogGaborTransform(object):
    def __init__(self, K=K, color=color, verbose=False):
        self.K = K
        self.color = color
        self.verbose = verbose

    def __call__(self, cropped_pyr):
        img = cropped_pyr[0]
        img_crop = cropped_pyr[1]
        log_gabor_coeffs = log_gabor_transform(img_crop.unsqueeze(1), K, color=self.color)
        
        return img, log_gabor_coeffs

# %%
class LogGaborReshape(object):
    def __init__(self, n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color, verbose=False):
        self.n_levels = n_levels
        self.n_color = n_color
        self.n_eccentricity = n_eccentricity 
        self.n_azimuth = n_azimuth 
        self.n_theta = n_theta
        self.n_phase = n_phase  
        self.color = color
        self.verbose = verbose

    def __call__(self, log_gabor_transform):
        img = log_gabor_transform[0]
        log_gabor_coeffs = log_gabor_transform[1]
        log_gabor_coeffs = log_gabor_coeffs.permute(1, 4, 5, 0, 2, 3).contiguous()
        log_gabor_coeffs = log_gabor_coeffs.view(self.n_color*self.n_theta*self.n_phase, 
                                                 self.n_levels * self.n_eccentricity, 
                                                 self.n_azimuth)
 
        return img, log_gabor_coeffs

# %% [markdown]
# ### Inverse transformations (for display only)

# %%
class LogGaborInvReshape(object):
    def __init__(self, n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color, verbose=False):
        self.n_levels = n_levels
        self.n_color = n_color
        self.n_eccentricity = n_eccentricity 
        self.n_azimuth = n_azimuth 
        self.n_theta = n_theta
        self.n_phase = n_phase  
        self.color = color
        self.verbose = verbose
    
    def __call__(self, log_gabor_coeffs):

        if self.verbose:
            print('log_gabor_coeffs.shape:', log_gabor_coeffs.shape)
        log_gabor_coeffs = log_gabor_coeffs.view(-1, 
                                                 self.n_color, 
                                                 self.n_theta, 
                                                 self.n_phase, 
                                                 self.n_levels, 
                                                 self.n_eccentricity, 
                                                 self.n_azimuth)
        log_gabor_coeffs = log_gabor_coeffs.permute(0, 4, 1, 5, 6, 2, 3).contiguous()
        return log_gabor_coeffs

# %%
class LogGaborInvTransform(object):
    def __init__(self, K_inv=K_inv, color=color, verbose=False):
        self.K_inv = K_inv
        self.color = color
        self.verbose = verbose
    
    def __call__(self, log_gabor_coeffs):
        img_crop=inverse_gabor(log_gabor_coeffs[:, :, 0, ...].detach(), K_inv, self.verbose)
        if self.verbose:
            print('img_crop.shape:', img_crop.shape)

        return img_crop

# %%
class InvCroppedPyramid(object):
    def __init__(self, 
                 #width, 
                 base_levels, 
                 color=color, 
                 #do_mask=do_mask, 
                 verbose=False, 
                 n_levels=None, 
                 color_mode='rgb'):
        #self.width = width
        self.base_levels = base_levels
        self.color = color
        #self.do_mask = do_mask
        self.verbose = verbose
        self.n_levels = n_levels
        self.color_mode = color_mode

    def __call__(self, img_crop):
        full_img_rec = inverse_pyramid(img_crop, 
                                       N_X = 128,
                                       N_Y = 128,
                                       #width=self.width, 
                                       base_levels=self.base_levels,
                                       color=self.color, 
                                       #do_mask=self.do_mask, 
                                       verbose=self.verbose,
                                       #squeeze=True,
                                       gauss=gauss,
                                       n_levels=self.n_levels)
                                       #color_mode=self.color_mode)
        return full_img_rec

# %% [markdown]
# # Exploring the MNIST with where noise parameters and log polar encoding

# %% [markdown]
# - 128x128 pixel with shift, noise and circular mask

# %%
args.offset_max = 40 #like in the paper

# %%
args.offset_std = 30
args.contrast = 0.7

width = 32

n_levels = 2 

base_levels = 2

n_color = 1

r_min = width / 4

r_max = width / 2 

n_sublevel = n_eccentricity = 2

n_azimuth = 16

n_theta = 8

n_phase = 1

"""
width = 64

n_levels = 2 

base_levels = 2

n_color = 1

r_min = width / 4 

r_max = width / 2 

n_sublevel = n_eccentricity = 4

n_azimuth = 16 *2

n_theta = 8

n_phase = 1
"""
# Out:
# '\nwidth = 64\n\nn_levels = 2 \n\nbase_levels = 2\n\nn_color = 1\n\nr_min = width / 4 \n\nr_max = width / 2 \n\nn_sublevel = n_eccentricity = 4\n\nn_azimuth = 16 *2\n\nn_theta = 8\n\nn_phase = 1\n'

# %%
transform_big = transforms.Compose([
    RetinaFill(N_pic=args.N_pic),
    WhereShift(args),
    RetinaBackground(contrast=args.contrast,
                     noise=args.noise,
                     sf_0=args.sf_0,
                     B_sf=args.B_sf, flexible=True),
    RetinaMask(N_pic=args.N_pic),
    transforms.ToTensor(),
    CroppedPyramid(width, 
                  base_levels, 
                  n_levels=n_levels),
    LogGaborTransform(color=color),
    LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color),

])

# %%
train_loader = torch.utils.data.DataLoader(MNIST('../data',
                        train=True,
                        download=True,
                        transform=transform_big,
                        ),
                        batch_size=args.minibatch_size,
                        shuffle=True)

test_loader = torch.utils.data.DataLoader(MNIST('../data',
                        train=False,
                        download=True,
                        transform=transform_big,
                        ),
                        batch_size=args.minibatch_size,
                        shuffle=True)

# %%
data, label = next(iter(train_loader))
data_original = data[0]
data_polo = data[1]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-51-4c792bb4c34a> in <module>
# ----> 1 data, label = next(iter(train_loader))
#       2 data_original = data[0]
#       3 data_polo = data[1]
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/internship/int-lab-book/src/what_where/main.py in __getitem__(self, index)
#      86
#      87         if self.transform is not None:
# ---> 88             img = self.transform((img, index))
#      89
#      90         if self.target_transform is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# <ipython-input-17-bd0d32696996> in __call__(self, cropped_pyr)
#       8         img = cropped_pyr[0]
#       9         img_crop = cropped_pyr[1]
# ---> 10         log_gabor_coeffs = log_gabor_transform(img_crop.unsqueeze(1), K, color=self.color)
#      11
#      12         return img, log_gabor_coeffs
#
# ~/internship/int-lab-book/src/POLO/PYramid2.py in log_gabor_transform(img_crop, K, color)
#     462         return torch.cat((chan_0, chan_1, chan_2), dim=2)
#     463     else:
# --> 464         return torch.tensordot(img_crop[:,:,:,:], K,  dims=2)
#     465
#     466
#
# ~/anaconda3/lib/python3.8/site-packages/torch/functional.py in tensordot(a, b, dims)
#     934         dims_a = list(range(-dims, 0))
#     935         dims_b = list(range(dims))
# --> 936     return _VF.tensordot(a, b, dims_a, dims_b)  # type: ignore
#     937
#     938 def cartesian_prod(*tensors):
#
# RuntimeError: contracted dimensions need to match, but first has size 32 in dim -2 and second has size 64 in dim 0

# %%
data_original.shape, data_polo.shape
# Out:
# (torch.Size([100, 1, 128, 128]), torch.Size([100, 8, 8, 32]))

# %% [markdown]
# ### Displaying Log Gabor Encoded visual field using pseudo-inverse transformation

# %%
inverse_transform = transforms.Compose([
    LogGaborInvReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color, verbose=False),
    LogGaborInvTransform(K_inv=K_inv, color=color, verbose=False),
    InvCroppedPyramid(base_levels, n_levels=n_levels, verbose=False),
])

# %% [markdown]
# - The Log-Polar compressed format

# %%
full_img_rec = inverse_transform(data_polo)

# %%
polo = view_data(full_img_rec, label, 5)

# %% [markdown]
# - The original format

# %%
original = view_data(data_original, label, 5)

# %% [markdown]
# # Creating an Attention Transformer model with log-polar entry (POLO-STN)

# %%
class Polo_AttentionTransNet(nn.Module):
    
    def __init__(self):
        super(Polo_AttentionTransNet, self).__init__()

        ##  The what pathway
        self.conv1 = nn.Conv2d(1, 20, 5)
        self.conv2 = nn.Conv2d(20, 50, 5)
        self.fc1 = nn.Linear(4 * 4 * 50, 500)
        self.fc2 = nn.Linear(500, 10)

        self.fc_loc = nn.Sequential(nn.Linear(8 * 10 * 16, 32),
                                    nn.ReLU(True),
                                    nn.Linear(32, 2))

        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.zero_()

        self.downscale = nn.Parameter(torch.tensor([[0.2, 0], [0, 0.2]],
                                                   dtype=torch.float),
                                      requires_grad=False)

    def stn(self: object, x: torch.Tensor, x_polo: torch.Tensor) -> Tuple[torch.Tensor]:
    
        xs = x_polo.view(-1, 8 * 10 * 16)
        theta = self.fc_loc(xs)

        theta = torch.cat((self.downscale.unsqueeze(0).repeat(
            theta.size(0), 1, 1), theta.unsqueeze(2)),
                          dim=2)
        
        #theta = theta.view(-1, 2, 3)
        
        grid_size = torch.Size([x.size()[0], x.size()[1], 28, 28])
        grid = F.affine_grid(theta, grid_size)
        x = F.grid_sample(x, grid)

        return x, theta

    def forward(self, x, x_polo):
        # transform the input
        x, _ = self.stn(x, x_polo)

        # Perform the usual forward pass
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)

        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)

        x = x.view(-1, 4 * 4 * 50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load("../models/low_comp_polo_stn.pt")
#model = Polo_AttentionTransNet().to(device)

# %%
def train(epoch, loader):
    model.train()
    for batch_idx, (data, target) in enumerate(loader):

        data_original, data_polo = data[0], data[1]
        data_original, data_polo, target = data_original.to(
            device, dtype=torch.double), data_polo.to(
                device, dtype=torch.double), target.to(device)

        optimizer.zero_grad()
        output = model(data_original, data_polo)
        loss = loss_func(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {}/{} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, args.epochs, batch_idx * len(data_original),
                len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test(loader):
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in loader:
            data_original, data_polo = data[0], data[1]
            data_original, data_polo, target = data_original.to(
                device, dtype=torch.double), data_polo.to(
                    device, dtype=torch.double), target.to(device)

            output = model(data_original, data_polo)

            # sum up batch loss
            #test_loss += F.nll_loss(output, target, size_average=False).item()
            test_loss += loss_func(output, target).item()
            # get the index of the max log-probability
            #pred = output.max(1, keepdim=True)[1]
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, len(test_loader.dataset),
                     100. * correct / len(test_loader.dataset)))
        return correct / len(test_loader.dataset)

# %% [markdown]
# # Training parameters of the What/Where model

# %%
eccentricities = np.linspace(args.offset_max, 0, 9, endpoint=False)[::-1]
eccentricities
# Out:
# array([ 4.44444444,  8.88888889, 13.33333333, 17.77777778, 22.22222222,
#        26.66666667, 31.11111111, 35.55555556, 40.        ])

# %%
contrasts = (0.7, 0.5, 0.3)

# %% [markdown]
# # Training on contrast 0.7

# %%
optimizer = optim.SGD(model.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5, last_epoch=-1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-03.

# %%
acc = []

# %%
for offset in eccentricities:

    args.offset_std = offset
    
    transform_big = transforms.Compose([
        RetinaFill(N_pic=args.N_pic),
        WhereShift(args),
        RetinaBackground(contrast=args.contrast,
                         noise=args.noise,
                         sf_0=args.sf_0,
                         B_sf=args.B_sf, flexible=True),
        RetinaMask(N_pic=args.N_pic),
        transforms.ToTensor(),
        CroppedPyramid(width, 
                       base_levels, 
                       n_levels=n_levels),
        LogGaborTransform(color=color),
        LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color)
    ])


    train_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=True,
        download=True,
        transform=transform_big,
    ),
                                               batch_size=args.minibatch_size,
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=False,
        download=True,
        transform=transform_big,
    ),
                                              batch_size=args.minibatch_size,
                                              shuffle=True)

    print("Training on eccentricity=%s" % (offset))
    args.epochs = 10

    for epoch in range(1, args.epochs + 1):
        train(epoch, train_loader)
        curr_acc = test(test_loader)
        acc.append(curr_acc)
        scheduler.step()
# Out:
# Training on eccentricity=4.444444444444443
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 2.304824
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 2.302098
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 2.296112
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 2.288450
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 2.293853
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 2.296762
#
# Test set: Average loss: 0.0229, Accuracy: 2590/10000 (26%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 2.286909
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 2.291198
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 2.285929
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 2.275550
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 2.269142
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 2.262704
#
# Test set: Average loss: 0.0225, Accuracy: 2774/10000 (28%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 2.260594
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 2.227540
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 2.255083
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 2.162227
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 2.129756
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 2.120212
#
# Test set: Average loss: 0.0201, Accuracy: 3477/10000 (35%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.993940
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.910674
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 2.000810
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 2.211553
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 2.241539
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.976924
#
# Test set: Average loss: 0.0169, Accuracy: 4752/10000 (48%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.698224
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.786922
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.908159
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.765427
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.716870
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.947462
#
# Test set: Average loss: 0.0177, Accuracy: 4018/10000 (40%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.784815
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.955431
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 2.186677
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.651407
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.987095
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.531231
#
# Test set: Average loss: 0.0177, Accuracy: 4234/10000 (42%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.746402
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.818594
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.493306
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.709829
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.583957
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.763056
#
# Test set: Average loss: 0.0134, Accuracy: 5805/10000 (58%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.253290
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.293612
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.438834
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 2.103209
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.711667
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.354494
#
# Test set: Average loss: 0.0113, Accuracy: 6424/10000 (64%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.155010
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.647154
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.848737
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.435376
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.462919
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.112368
#
# Test set: Average loss: 0.0115, Accuracy: 6349/10000 (63%)
#
# Adjusting learning rate of group 0 to 5.0000e-03.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.177376
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.203224
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.135854
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.130973
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 0.854061
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.509115
#
# Test set: Average loss: 0.0089, Accuracy: 7344/10000 (73%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Training on eccentricity=8.888888888888886
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.309859
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 0.947507
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.302334
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 0.969741
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.156317
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.027382
#
# Test set: Average loss: 0.0097, Accuracy: 7135/10000 (71%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.039853
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 0.884402
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 0.811825
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.060095
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 0.777880
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 0.988617
#
# Test set: Average loss: 0.0098, Accuracy: 7003/10000 (70%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.119693
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.030326
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.147521
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 0.708269
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 0.818010
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 0.793850
#
# Test set: Average loss: 0.0091, Accuracy: 7173/10000 (72%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 0.981640
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.003968
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 0.951372
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 0.927143
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 0.906285
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 0.612215
#
# Test set: Average loss: 0.0082, Accuracy: 7551/10000 (76%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 0.821015
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 0.743417
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 0.859385
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 0.678821
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 0.870276
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.019188
#
# Test set: Average loss: 0.0076, Accuracy: 7688/10000 (77%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 0.671887
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.014961
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 0.803236
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 0.777294
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 0.906157
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 0.899092
#
# Test set: Average loss: 0.0073, Accuracy: 7814/10000 (78%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 0.615505
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 0.711640
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 0.863223
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 0.811065
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 0.749980
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 0.853005
#
# Test set: Average loss: 0.0075, Accuracy: 7694/10000 (77%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 0.733069
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 0.714957
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 0.679707
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 0.825905
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 0.789973
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 0.763992
#
# Test set: Average loss: 0.0070, Accuracy: 7877/10000 (79%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 0.668662
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 0.781192
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 0.757299
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 0.737956
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 0.648470
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 0.645753
#
# Test set: Average loss: 0.0068, Accuracy: 7965/10000 (80%)
#
# Adjusting learning rate of group 0 to 2.5000e-03.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 0.714236
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 0.583881
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 0.668022
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 0.759575
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 0.714084
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 0.567950
#
# Test set: Average loss: 0.0066, Accuracy: 8018/10000 (80%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Training on eccentricity=13.333333333333332
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 0.964700
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 0.951190
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 0.897583
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 0.970115
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 0.992329
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 0.725518
#
# Test set: Average loss: 0.0085, Accuracy: 7401/10000 (74%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 0.590867
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 0.725823
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 0.972417
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 0.885644
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 0.835286
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 0.879906
#
# Test set: Average loss: 0.0083, Accuracy: 7480/10000 (75%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 0.835348
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 0.912676
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 0.680057
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 0.763796
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 0.922755
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 0.958321
#
# Test set: Average loss: 0.0083, Accuracy: 7520/10000 (75%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 0.794114
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 0.864357
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 0.908078
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 0.848778
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 0.630500
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 0.733925
#
# Test set: Average loss: 0.0079, Accuracy: 7609/10000 (76%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 0.536516
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 0.889667
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 0.727333
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 0.783152
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 0.796297
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 0.905534
#
# Test set: Average loss: 0.0080, Accuracy: 7548/10000 (75%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 0.983538
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 0.828119
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 0.953328
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.030741
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 0.776964
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 0.870132
#
# Test set: Average loss: 0.0076, Accuracy: 7696/10000 (77%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 0.696728
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 0.715527
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 0.857549
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 0.607277
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 0.729396
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 0.722837
#
# Test set: Average loss: 0.0077, Accuracy: 7664/10000 (77%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 0.857294
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 0.802563
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 0.611310
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 0.784527
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 0.854967
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 0.694628
#
# Test set: Average loss: 0.0077, Accuracy: 7650/10000 (76%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 0.693102
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 0.562473
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 0.854585
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 0.716719
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.033561
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 0.804398
#
# Test set: Average loss: 0.0075, Accuracy: 7695/10000 (77%)
#
# Adjusting learning rate of group 0 to 1.2500e-03.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 0.842700
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 0.725341
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 0.875895
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 0.700715
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 0.847431
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 0.605060
#
# Test set: Average loss: 0.0074, Accuracy: 7755/10000 (78%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Training on eccentricity=17.77777777777778
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 0.864277
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 0.953870
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 0.806901
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 0.768143
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 0.825883
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 0.961138
#
# Test set: Average loss: 0.0094, Accuracy: 7060/10000 (71%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 0.916954
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 0.817612
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.036574
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.020766
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.233761
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 0.964649
#
# Test set: Average loss: 0.0092, Accuracy: 7144/10000 (71%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.087381
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 0.927739
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 0.984244
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 0.835935
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 0.976228
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 0.731525
#
# Test set: Average loss: 0.0092, Accuracy: 7118/10000 (71%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 0.761023
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 0.868731
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.016230
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.034844
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 0.946042
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 0.924217
#
# Test set: Average loss: 0.0091, Accuracy: 7178/10000 (72%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.118137
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 0.773825
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 0.875355
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 0.930169
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 0.857625
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 0.863502
#
# Test set: Average loss: 0.0089, Accuracy: 7236/10000 (72%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.038236
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 0.770625
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 0.894792
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.032683
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.078653
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.008704
#
# Test set: Average loss: 0.0090, Accuracy: 7204/10000 (72%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 0.969977
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 0.844441
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 0.838905
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 0.795030
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 0.733031
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 0.833454
#
# Test set: Average loss: 0.0087, Accuracy: 7320/10000 (73%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 0.777001
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 0.943769
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 0.774525
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.092721
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 0.757565
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 0.866300
#
# Test set: Average loss: 0.0088, Accuracy: 7237/10000 (72%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 0.607502
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 0.582534
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 0.933634
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 0.922461
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 0.646337
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 0.903107
#
# Test set: Average loss: 0.0087, Accuracy: 7321/10000 (73%)
#
# Adjusting learning rate of group 0 to 6.2500e-04.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 0.882585
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 0.795757
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 0.841111
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 0.658693
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 0.973316
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 0.786052
#
# Test set: Average loss: 0.0088, Accuracy: 7275/10000 (73%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Training on eccentricity=22.22222222222222
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.037157
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 0.927531
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 0.997232
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.195121
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.178436
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.067292
#
# Test set: Average loss: 0.0104, Accuracy: 6685/10000 (67%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.062358
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.090311
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.093776
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.130200
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.067224
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 0.902058
#
# Test set: Average loss: 0.0103, Accuracy: 6745/10000 (67%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.325458
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.093536
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.105920
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.001775
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.007710
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.052234
#
# Test set: Average loss: 0.0103, Accuracy: 6722/10000 (67%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.150342
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.016437
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.248478
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 0.996215
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.021565
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.006662
#
# Test set: Average loss: 0.0102, Accuracy: 6734/10000 (67%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.028814
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.301645
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.029928
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 0.988091
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 0.939295
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.041302
#
# Test set: Average loss: 0.0103, Accuracy: 6694/10000 (67%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.316392
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.083624
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.102278
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 0.890010
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.145843
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.123365
#
# Test set: Average loss: 0.0102, Accuracy: 6767/10000 (68%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.042568
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.168955
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 0.982678
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.091932
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.287954
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 0.896215
#
# Test set: Average loss: 0.0102, Accuracy: 6765/10000 (68%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.095873
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.108468
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.115303
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.013891
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.075682
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 0.971037
#
# Test set: Average loss: 0.0102, Accuracy: 6767/10000 (68%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.037823
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 0.976486
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 0.848244
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.055139
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.097385
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.030890
#
# Test set: Average loss: 0.0101, Accuracy: 6760/10000 (68%)
#
# Adjusting learning rate of group 0 to 3.1250e-04.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.058244
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.076954
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.079235
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 0.929434
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.036841
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.066390
#
# Test set: Average loss: 0.0101, Accuracy: 6767/10000 (68%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Training on eccentricity=26.666666666666664
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.030634
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.316394
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.226993
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.250356
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.183623
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.028698
#
# Test set: Average loss: 0.0120, Accuracy: 6097/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.051249
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.328875
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.226756
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.042351
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.182455
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 0.943199
#
# Test set: Average loss: 0.0119, Accuracy: 6113/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.242681
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.293380
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 0.981245
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.176738
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.268168
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.096161
#
# Test set: Average loss: 0.0119, Accuracy: 6112/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.247218
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.104146
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.234788
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.174464
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.051899
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.292619
#
# Test set: Average loss: 0.0119, Accuracy: 6111/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.167331
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.182185
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.078753
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.202430
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.022587
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.051668
#
# Test set: Average loss: 0.0118, Accuracy: 6116/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.025998
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.035084
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.019717
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.178364
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.359344
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.147642
#
# Test set: Average loss: 0.0118, Accuracy: 6119/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.132844
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.136352
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.212086
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.244005
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.188256
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.119679
#
# Test set: Average loss: 0.0118, Accuracy: 6168/10000 (62%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.256918
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.085904
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 0.960262
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.041607
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.068683
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.246851
#
# Test set: Average loss: 0.0117, Accuracy: 6148/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.031570
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.014203
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.114413
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.156891
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.038327
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.188153
#
# Test set: Average loss: 0.0117, Accuracy: 6136/10000 (61%)
#
# Adjusting learning rate of group 0 to 1.5625e-04.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.266341
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 0.994164
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.327362
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.276510
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.022709
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.082669
#
# Test set: Average loss: 0.0117, Accuracy: 6140/10000 (61%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Training on eccentricity=31.11111111111111
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.358377
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.208612
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.361797
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.259650
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.341809
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.227729
#
# Test set: Average loss: 0.0128, Accuracy: 5647/10000 (56%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.308223
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.164487
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.303697
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.338988
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.164890
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 1.455948
#
# Test set: Average loss: 0.0128, Accuracy: 5675/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.077923
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.284047
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.444381
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.229455
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.459533
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.274383
#
# Test set: Average loss: 0.0128, Accuracy: 5699/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.398938
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.205752
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.363327
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.329535
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.279493
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.490413
#
# Test set: Average loss: 0.0128, Accuracy: 5696/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.306205
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.331430
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.149689
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.461932
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.460693
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.198198
#
# Test set: Average loss: 0.0128, Accuracy: 5687/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.306344
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.227349
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.260393
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.345465
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.412101
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.106286
#
# Test set: Average loss: 0.0128, Accuracy: 5704/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.187483
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 0.971711
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.303422
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.309498
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.130831
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.229933
#
# Test set: Average loss: 0.0128, Accuracy: 5691/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.309597
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.313664
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.194070
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.304060
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.278613
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.343858
#
# Test set: Average loss: 0.0128, Accuracy: 5661/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.206936
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.132751
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.431583
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.478374
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.115059
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.190764
#
# Test set: Average loss: 0.0127, Accuracy: 5680/10000 (57%)
#
# Adjusting learning rate of group 0 to 7.8125e-05.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.342715
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.357588
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.267988
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.175140
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.320569
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.018343
#
# Test set: Average loss: 0.0127, Accuracy: 5695/10000 (57%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Training on eccentricity=35.55555555555556
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.168081
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.345571
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.343283
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.463603
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.248861
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.258473
#
# Test set: Average loss: 0.0139, Accuracy: 5209/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.454003
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.414286
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.472782
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.284818
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.445996
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 1.419905
#
# Test set: Average loss: 0.0139, Accuracy: 5211/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.265509
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.462476
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.448541
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.511152
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.249340
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.493438
#
# Test set: Average loss: 0.0139, Accuracy: 5208/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.421470
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.356624
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.498959
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.406684
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.304369
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.577082
#
# Test set: Average loss: 0.0139, Accuracy: 5201/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.325264
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.339508
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.495816
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.317102
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.328245
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.536222
#
# Test set: Average loss: 0.0139, Accuracy: 5221/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.252119
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.419416
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.536377
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.302278
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.228483
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.377901
#
# Test set: Average loss: 0.0139, Accuracy: 5232/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.083472
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.235519
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.423173
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.493738
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.152968
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.413103
#
# Test set: Average loss: 0.0139, Accuracy: 5233/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.457502
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.279719
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.290652
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.517582
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.347293
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.506927
#
# Test set: Average loss: 0.0139, Accuracy: 5233/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.388601
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.233693
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.415883
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.191678
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.221947
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.280041
#
# Test set: Average loss: 0.0139, Accuracy: 5230/10000 (52%)
#
# Adjusting learning rate of group 0 to 3.9063e-05.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.408138
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.357977
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.529754
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.513339
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.457446
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.381081
#
# Test set: Average loss: 0.0139, Accuracy: 5228/10000 (52%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Training on eccentricity=40.0
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.659953
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.485747
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.635551
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.698814
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.274061
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.645949
#
# Test set: Average loss: 0.0147, Accuracy: 4939/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.705904
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.192220
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.642685
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.330933
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.125422
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 1.408244
#
# Test set: Average loss: 0.0147, Accuracy: 4918/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.401439
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.646842
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.598388
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.435507
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.568823
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.490077
#
# Test set: Average loss: 0.0147, Accuracy: 4936/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.461273
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.547079
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.489518
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.582771
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.360253
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.526691
#
# Test set: Average loss: 0.0147, Accuracy: 4939/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.448466
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.509725
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.591109
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.614014
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.512287
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.324362
#
# Test set: Average loss: 0.0147, Accuracy: 4941/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.378522
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.590826
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.561924
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.380292
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.564559
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.607658
#
# Test set: Average loss: 0.0147, Accuracy: 4937/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.386565
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.473139
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.445207
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.820059
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.489866
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.550634
#
# Test set: Average loss: 0.0147, Accuracy: 4952/10000 (50%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.401875
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.510420
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.598878
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.589620
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.598201
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.434875
#
# Test set: Average loss: 0.0147, Accuracy: 4946/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.538861
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.632470
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.849490
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.397192
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.343317
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.610719
#
# Test set: Average loss: 0.0147, Accuracy: 4938/10000 (49%)
#
# Adjusting learning rate of group 0 to 1.9531e-05.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.648389
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.651050
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.524075
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.643981
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.483050
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.403478
#
# Test set: Average loss: 0.0146, Accuracy: 4951/10000 (50%)
#
# Adjusting learning rate of group 0 to 9.7656e-06.

# %%
torch.save(model, "../models/low_comp_polo_stn.pt")

# %% [markdown]
# # Training on lesser contrasts

# %%
optimizer = optim.SGD(model.parameters(), lr=0.0005)
loss_func = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5, last_epoch=-1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-04.

# %%
for contrast in (0.5, 0.3):

    print("training on contrast %s" %(contrast))

    args.offset_std = 40 #train while the maximum range is 40
    args.contrast = contrast
    transform_big = transforms.Compose([
        RetinaFill(N_pic=args.N_pic),
        WhereShift(args),
        RetinaBackground(contrast=args.contrast,
                         noise=args.noise,
                         sf_0=args.sf_0,
                         B_sf=args.B_sf, flexible=True),
        RetinaMask(N_pic=args.N_pic),
        transforms.ToTensor(),
        CroppedPyramid(width, 
                       base_levels, 
                       n_levels=n_levels),
        LogGaborTransform(color=color),
        LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color)
    ])


    train_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=True,
        download=True,
        transform=transform_big,
    ),
                                               batch_size=args.minibatch_size,
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=False,
        download=True,
        transform=transform_big,
    ),
                                              batch_size=args.minibatch_size,
                                              shuffle=True)

    print("Training on eccentricity=%s" % (args.offset_std))
    args.epochs = 10

    for epoch in range(1, args.epochs + 1):
        train(epoch, train_loader)
        curr_acc = test(test_loader)
        #acc.append(curr_acc)
        scheduler.step()
# Out:
# training on contrast 0.5
# Training on eccentricity=40
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.633242
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.553903
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.806279
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.512287
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.661976
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.735040
#
# Test set: Average loss: 0.0159, Accuracy: 4535/10000 (45%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.621532
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.642105
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.503662
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 1.547806
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.658064
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 1.639545
#
# Test set: Average loss: 0.0158, Accuracy: 4533/10000 (45%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.593173
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.575660
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.489042
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.465499
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.660017
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.721967
#
# Test set: Average loss: 0.0160, Accuracy: 4456/10000 (45%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.448968
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.594418
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.712319
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.576983
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.547299
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.422722
#
# Test set: Average loss: 0.0158, Accuracy: 4569/10000 (46%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.621600
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.551089
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.677788
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.448416
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.677992
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.586700
#
# Test set: Average loss: 0.0158, Accuracy: 4531/10000 (45%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.551299
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.440990
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.688431
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.668431
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.810362
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.519470
#
# Test set: Average loss: 0.0157, Accuracy: 4640/10000 (46%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.415623
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.545930
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.508256
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.538896
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.691580
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.519210
#
# Test set: Average loss: 0.0155, Accuracy: 4650/10000 (46%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.551143
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.618435
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.431460
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.470187
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.520048
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.458095
#
# Test set: Average loss: 0.0155, Accuracy: 4648/10000 (46%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.317485
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.560471
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.535089
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.468152
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.493705
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.514050
#
# Test set: Average loss: 0.0154, Accuracy: 4720/10000 (47%)
#
# Adjusting learning rate of group 0 to 5.0000e-04.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.482870
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.606723
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.518111
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.679778
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.397547
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.628993
#
# Test set: Average loss: 0.0153, Accuracy: 4810/10000 (48%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# training on contrast 0.3
# Training on eccentricity=40
# Train Epoch: 1/10 [0/60000 (0%)]	Loss: 1.783424
# Train Epoch: 1/10 [10000/60000 (17%)]	Loss: 1.734927
# Train Epoch: 1/10 [20000/60000 (33%)]	Loss: 1.777648
# Train Epoch: 1/10 [30000/60000 (50%)]	Loss: 1.733321
# Train Epoch: 1/10 [40000/60000 (67%)]	Loss: 1.659796
# Train Epoch: 1/10 [50000/60000 (83%)]	Loss: 1.880861
#
# Test set: Average loss: 0.0174, Accuracy: 4058/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 2/10 [0/60000 (0%)]	Loss: 1.855462
# Train Epoch: 2/10 [10000/60000 (17%)]	Loss: 1.767485
# Train Epoch: 2/10 [20000/60000 (33%)]	Loss: 1.697956
# Train Epoch: 2/10 [30000/60000 (50%)]	Loss: 2.033694
# Train Epoch: 2/10 [40000/60000 (67%)]	Loss: 1.840006
# Train Epoch: 2/10 [50000/60000 (83%)]	Loss: 1.711796
#
# Test set: Average loss: 0.0172, Accuracy: 4112/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 3/10 [0/60000 (0%)]	Loss: 1.713791
# Train Epoch: 3/10 [10000/60000 (17%)]	Loss: 1.606396
# Train Epoch: 3/10 [20000/60000 (33%)]	Loss: 1.797711
# Train Epoch: 3/10 [30000/60000 (50%)]	Loss: 1.783384
# Train Epoch: 3/10 [40000/60000 (67%)]	Loss: 1.759053
# Train Epoch: 3/10 [50000/60000 (83%)]	Loss: 1.793497
#
# Test set: Average loss: 0.0172, Accuracy: 4088/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 4/10 [0/60000 (0%)]	Loss: 1.609213
# Train Epoch: 4/10 [10000/60000 (17%)]	Loss: 1.785914
# Train Epoch: 4/10 [20000/60000 (33%)]	Loss: 1.771561
# Train Epoch: 4/10 [30000/60000 (50%)]	Loss: 1.729181
# Train Epoch: 4/10 [40000/60000 (67%)]	Loss: 1.964783
# Train Epoch: 4/10 [50000/60000 (83%)]	Loss: 1.681672
#
# Test set: Average loss: 0.0171, Accuracy: 4131/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 5/10 [0/60000 (0%)]	Loss: 1.829269
# Train Epoch: 5/10 [10000/60000 (17%)]	Loss: 1.744526
# Train Epoch: 5/10 [20000/60000 (33%)]	Loss: 1.805823
# Train Epoch: 5/10 [30000/60000 (50%)]	Loss: 1.691236
# Train Epoch: 5/10 [40000/60000 (67%)]	Loss: 1.838654
# Train Epoch: 5/10 [50000/60000 (83%)]	Loss: 1.635375
#
# Test set: Average loss: 0.0171, Accuracy: 4127/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 6/10 [0/60000 (0%)]	Loss: 1.823981
# Train Epoch: 6/10 [10000/60000 (17%)]	Loss: 1.622133
# Train Epoch: 6/10 [20000/60000 (33%)]	Loss: 1.779734
# Train Epoch: 6/10 [30000/60000 (50%)]	Loss: 1.716338
# Train Epoch: 6/10 [40000/60000 (67%)]	Loss: 1.599698
# Train Epoch: 6/10 [50000/60000 (83%)]	Loss: 1.800880
#
# Test set: Average loss: 0.0171, Accuracy: 4122/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 7/10 [0/60000 (0%)]	Loss: 1.759341
# Train Epoch: 7/10 [10000/60000 (17%)]	Loss: 1.846083
# Train Epoch: 7/10 [20000/60000 (33%)]	Loss: 1.779349
# Train Epoch: 7/10 [30000/60000 (50%)]	Loss: 1.697148
# Train Epoch: 7/10 [40000/60000 (67%)]	Loss: 1.853874
# Train Epoch: 7/10 [50000/60000 (83%)]	Loss: 1.757772
#
# Test set: Average loss: 0.0170, Accuracy: 4165/10000 (42%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 8/10 [0/60000 (0%)]	Loss: 1.734325
# Train Epoch: 8/10 [10000/60000 (17%)]	Loss: 1.746574
# Train Epoch: 8/10 [20000/60000 (33%)]	Loss: 1.672087
# Train Epoch: 8/10 [30000/60000 (50%)]	Loss: 1.547190
# Train Epoch: 8/10 [40000/60000 (67%)]	Loss: 1.688157
# Train Epoch: 8/10 [50000/60000 (83%)]	Loss: 1.731608
#
# Test set: Average loss: 0.0170, Accuracy: 4123/10000 (41%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 9/10 [0/60000 (0%)]	Loss: 1.639673
# Train Epoch: 9/10 [10000/60000 (17%)]	Loss: 1.758807
# Train Epoch: 9/10 [20000/60000 (33%)]	Loss: 1.687706
# Train Epoch: 9/10 [30000/60000 (50%)]	Loss: 1.726140
# Train Epoch: 9/10 [40000/60000 (67%)]	Loss: 1.723318
# Train Epoch: 9/10 [50000/60000 (83%)]	Loss: 1.661253
#
# Test set: Average loss: 0.0170, Accuracy: 4190/10000 (42%)
#
# Adjusting learning rate of group 0 to 2.5000e-04.
# Train Epoch: 10/10 [0/60000 (0%)]	Loss: 1.694650
# Train Epoch: 10/10 [10000/60000 (17%)]	Loss: 1.863745
# Train Epoch: 10/10 [20000/60000 (33%)]	Loss: 1.783724
# Train Epoch: 10/10 [30000/60000 (50%)]	Loss: 1.741706
# Train Epoch: 10/10 [40000/60000 (67%)]	Loss: 1.570687
# Train Epoch: 10/10 [50000/60000 (83%)]	Loss: 1.777238
#
# Test set: Average loss: 0.0170, Accuracy: 4156/10000 (42%)
#
# Adjusting learning rate of group 0 to 1.2500e-04.

# %% [markdown]
# # Saving the model

# %% [markdown]
# # Visualizing some transformations

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    #mean = np.array([0.485, 0.456, 0.406])
    #std = np.array([0.229, 0.224, 0.225])
    #inp = std * inp + mean
    #inp = np.clip(inp, 0, 1)
    return inp

thetas = []
def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        
        data, label = next(iter(test_loader))
        data_original = data[0][:16, :, :, :].to(device)
        data_polo = data[1][:16, :, :, :].to(device)
        
        input_tensor = data_original.cpu()
        
        output_tensor, theta = model.stn(data_original, data_polo)
        thetas.append(theta)
        
        #output_tensor = F.pad(input=output_tensor, pad=(50, 50, 50, 50), mode='constant', value=0)

        transformed_input_tensor = output_tensor.cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor, nrow=4))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor, nrow=4))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2, dpi=300)
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')
        axarr[0].set_xticks([0, 131])
        axarr[0].set_yticks([390])
        axarr[0].set_yticklabels([128])
        axarr[0].set_xticklabels([0, 128])

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')
        axarr[1].set_xticks([0, 30])
        axarr[1].set_yticks([90])
        axarr[1].set_yticklabels([28])
        axarr[1].set_xticklabels([0, 28])

        #f.savefig('../figures/polo_atn_attention.png')

# %%
visualize_stn()

# %%
thetas
# Out:
# [tensor([[[ 2.0000e-01,  0.0000e+00,  3.3849e-02],
#           [ 0.0000e+00,  2.0000e-01,  5.9151e-02]],
#
#          [[ 2.0000e-01,  0.0000e+00,  1.3353e-01],
#           [ 0.0000e+00,  2.0000e-01, -1.0791e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -3.9638e-01],
#           [ 0.0000e+00,  2.0000e-01, -4.8247e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -1.1474e-01],
#           [ 0.0000e+00,  2.0000e-01,  4.3950e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -9.5352e-02],
#           [ 0.0000e+00,  2.0000e-01,  3.0697e-03]],
#
#          [[ 2.0000e-01,  0.0000e+00, -2.0493e-01],
#           [ 0.0000e+00,  2.0000e-01,  5.1066e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00,  3.4638e-03],
#           [ 0.0000e+00,  2.0000e-01,  8.5904e-05]],
#
#          [[ 2.0000e-01,  0.0000e+00,  1.6142e-01],
#           [ 0.0000e+00,  2.0000e-01,  2.2147e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -2.3776e-02],
#           [ 0.0000e+00,  2.0000e-01,  5.2061e-02]],
#
#          [[ 2.0000e-01,  0.0000e+00,  2.2837e-01],
#           [ 0.0000e+00,  2.0000e-01,  1.3213e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -3.1454e-01],
#           [ 0.0000e+00,  2.0000e-01, -2.0383e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00,  2.3998e-01],
#           [ 0.0000e+00,  2.0000e-01,  1.7810e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -3.1119e-02],
#           [ 0.0000e+00,  2.0000e-01,  2.9689e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -1.0248e-01],
#           [ 0.0000e+00,  2.0000e-01,  1.7487e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00,  1.3471e-01],
#           [ 0.0000e+00,  2.0000e-01, -2.6348e-01]],
#
#          [[ 2.0000e-01,  0.0000e+00, -2.3051e-01],
#           [ 0.0000e+00,  2.0000e-01,  1.0585e-01]]], device='cuda:0')]

# %% [markdown]
# # Performance of the Polo-ATN

# %%
polo_atn_stats = {}

for contrast in contrasts:
    print("Testing on contrast = %s" % (contrast))

    accuracies = []

    for ecc in eccentricities:

        transform_big = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius=ecc),  # given eccentricity
            RetinaBackground(
                contrast=contrast,  # given contrast
                noise=args.noise,
                sf_0=args.sf_0,
                B_sf=args.B_sf,
                flexible=False),  # a fixed contrast
            RetinaMask(N_pic=args.N_pic),
            transforms.ToTensor(),
            CroppedPyramid(width, base_levels, n_levels=n_levels),
            LogGaborTransform(color=color),
            LogGaborReshape(n_levels,
                            n_color,
                            n_eccentricity,
                            n_azimuth,
                            n_theta,
                            n_phase,
                            color=color)
        ])
        train_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=True,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)

        test_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=False,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)
        print("Testing on eccentricity = %s" % (ecc))
        acc = test(test_loader)
        accuracies.append(acc)

    polo_atn_stats[contrast] = np.array(accuracies)
# Out:
# Testing on contrast = 0.7
# Testing on eccentricity = 4.444444444444443
#
# Test set: Average loss: 0.0047, Accuracy: 8658/10000 (87%)
#
# Testing on eccentricity = 8.888888888888886
#
# Test set: Average loss: 0.0052, Accuracy: 8503/10000 (85%)
#
# Testing on eccentricity = 13.333333333333332
#
# Test set: Average loss: 0.0074, Accuracy: 7641/10000 (76%)
#
# Testing on eccentricity = 17.77777777777778
#
# Test set: Average loss: 0.0102, Accuracy: 6651/10000 (67%)
#
# Testing on eccentricity = 22.22222222222222
#
# Test set: Average loss: 0.0137, Accuracy: 5330/10000 (53%)
#
# Testing on eccentricity = 26.666666666666664
#
# Test set: Average loss: 0.0161, Accuracy: 4472/10000 (45%)
#
# Testing on eccentricity = 31.11111111111111
#
# Test set: Average loss: 0.0176, Accuracy: 3875/10000 (39%)
#
# Testing on eccentricity = 35.55555555555556
#
# Test set: Average loss: 0.0195, Accuracy: 3247/10000 (32%)
#
# Testing on eccentricity = 40.0
#
# Test set: Average loss: 0.0212, Accuracy: 2542/10000 (25%)
#
# Testing on contrast = 0.5
# Testing on eccentricity = 4.444444444444443
#
# Test set: Average loss: 0.0085, Accuracy: 7786/10000 (78%)
#
# Testing on eccentricity = 8.888888888888886
#
# Test set: Average loss: 0.0091, Accuracy: 7471/10000 (75%)
#
# Testing on eccentricity = 13.333333333333332
#
# Test set: Average loss: 0.0106, Accuracy: 6867/10000 (69%)
#
# Testing on eccentricity = 17.77777777777778
#
# Test set: Average loss: 0.0131, Accuracy: 5807/10000 (58%)
#
# Testing on eccentricity = 22.22222222222222
#
# Test set: Average loss: 0.0154, Accuracy: 4809/10000 (48%)
#
# Testing on eccentricity = 26.666666666666664
#
# Test set: Average loss: 0.0173, Accuracy: 4076/10000 (41%)
#
# Testing on eccentricity = 31.11111111111111
#
# Test set: Average loss: 0.0193, Accuracy: 3247/10000 (32%)
#
# Testing on eccentricity = 35.55555555555556
#
# Test set: Average loss: 0.0211, Accuracy: 2402/10000 (24%)
#
# Testing on eccentricity = 40.0
#
# Test set: Average loss: 0.0229, Accuracy: 1672/10000 (17%)
#
# Testing on contrast = 0.3
# Testing on eccentricity = 4.444444444444443
#
# Test set: Average loss: 0.0176, Accuracy: 4538/10000 (45%)
#
# Testing on eccentricity = 8.888888888888886
#
# Test set: Average loss: 0.0181, Accuracy: 4296/10000 (43%)
#
# Testing on eccentricity = 13.333333333333332
#
# Test set: Average loss: 0.0193, Accuracy: 3560/10000 (36%)
#
# Testing on eccentricity = 17.77777777777778
#
# Test set: Average loss: 0.0203, Accuracy: 2990/10000 (30%)
#
# Testing on eccentricity = 22.22222222222222
#
# Test set: Average loss: 0.0214, Accuracy: 2478/10000 (25%)
#
# Testing on eccentricity = 26.666666666666664
#
# Test set: Average loss: 0.0224, Accuracy: 1969/10000 (20%)
#
# Testing on eccentricity = 31.11111111111111
#
# Test set: Average loss: 0.0232, Accuracy: 1532/10000 (15%)
#
# Testing on eccentricity = 35.55555555555556
#
# Test set: Average loss: 0.0238, Accuracy: 1268/10000 (13%)
#
# Testing on eccentricity = 40.0
#
# Test set: Average loss: 0.0241, Accuracy: 1115/10000 (11%)

# %%
polo_atn_stats
# Out:
# {0.7: array([0.8658, 0.8503, 0.7641, 0.6651, 0.533 , 0.4472, 0.3875, 0.3247,
#         0.2542]),
#  0.5: array([0.7786, 0.7471, 0.6867, 0.5807, 0.4809, 0.4076, 0.3247, 0.2402,
#         0.1672]),
#  0.3: array([0.4538, 0.4296, 0.356 , 0.299 , 0.2478, 0.1969, 0.1532, 0.1268,
#         0.1115])}
